# %% [markdown]
# # Ingest data from Kaggle dataset to Bronze layer via KaggleAPI

# %%
KAGGLE_DATASET: str = "nishiodens/japan-real-estate-transaction-prices"
BRONZE_DATA_DIR: str = "/lakehouse/default/Files/bronze"

KAGGLE_USERNAME: str = "haichaukhuu"
KAGGLE_KEY: str = "fa077ee3c23976817215f5295f55e856"
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 27, Finished, Available, Finished)

# %%
# abfss://fd5ed4b7-bdf8-4365-bdc3-ee2b3846f062@onelake.dfs.fabric.microsoft.com/a9ced147-3e0f-42a2-9ba9-5f25b3150d07/Files/bronze
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 28, Finished, Available, Finished)

# %%
# !pip install -q kaggle
# !pip install -q kagglehub
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 29, Finished, Available, Finished)

# %%
import os
os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
os.environ['KAGGLE_KEY'] = KAGGLE_KEY
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 30, Finished, Available, Finished)

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 31, Finished, Available, Finished)

# %%
print(os.getcwd())
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 32, Finished, Available, Finished)
# /lakehouse/default/Files/bronze

# %%
# !ls .
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 33, Finished, Available, Finished)
# prefecture_code.csv  trade_prices

# %%
os.chdir(BRONZE_DATA_DIR)
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 34, Finished, Available, Finished)

# %%
print(os.getcwd())
# !ls .
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 35, Finished, Available, Finished)
# /lakehouse/default/Files/bronze
# prefecture_code.csv  trade_prices

# %%
api.dataset_download_files(dataset = KAGGLE_DATASET, unzip=True)
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 36, Finished, Available, Finished)
# Dataset URL: https://www.kaggle.com/datasets/nishiodens/japan-real-estate-transaction-prices

# %%
BRONZE_DATA_PATH = f"{BRONZE_DATA_DIR}/{KAGGLE_DATASET}"
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 37, Finished, Available, Finished)

# %%
import json
from datetime import datetime


processing_status = "SUCCESS"
timestamp = datetime.now().isoformat()


exit_payload = {
    "status": processing_status,
    "completion_time": timestamp,
    "bronze_data_path": BRONZE_DATA_PATH,
    "message": "Data processing completed successfully."
}

exit_value_json = json.dumps(exit_payload)

print(f"Exiting notebook with value: {exit_value_json}")
mssparkutils.notebook.exit(exit_value_json)

print("This line will not be printed after exit.")
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 38, Finished, Available, Finished)
# Exiting notebook with value: {"status": "SUCCESS", "completion_time": "2025-06-16T08:11:49.009171", "bronze_data_path": "/lakehouse/default/Files/bronze/nishiodens/japan-real-estate-transaction-prices", "message": "Data processing completed successfully."}
# ExitValue: {"status": "SUCCESS", "completion_time": "2025-06-16T08:11:49.009171", "bronze_data_path": "/lakehouse/default/Files/bronze/nishiodens/japan-real-estate-transaction-prices", "message": "Data processing completed successfully."}
