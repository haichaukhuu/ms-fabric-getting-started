# %% [markdown]
# # Ingest data from Kaggle dataset to Bronze layer via KaggleAPI

# %%
KAGGLE_DATASET: str = "nishiodens/japan-real-estate-transaction-prices"
BRONZE_DATA_PATH: str = "/lakehouse/default/Files/bronze"

KAGGLE_USERNAME: str = "haichaukhuu"
KAGGLE_KEY: str = "fa077ee3c23976817215f5295f55e856"
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 23, Finished, Available, Finished)

# %%
# abfss://fd5ed4b7-bdf8-4365-bdc3-ee2b3846f062@onelake.dfs.fabric.microsoft.com/a9ced147-3e0f-42a2-9ba9-5f25b3150d07/Files/bronze
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 14, Finished, Available, Finished)

# %%
# !pip install -q kaggle
# !pip install -q kagglehub
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 15, Finished, Available, Finished)

# %%
import os
os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
os.environ['KAGGLE_KEY'] = KAGGLE_KEY
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 16, Finished, Available, Finished)

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 17, Finished, Available, Finished)

# %%
print(os.getcwd())
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 18, Finished, Available, Finished)
# /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1750059579122_0001/container_1750059579122_0001_01_000001

# %%
# !ls .
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 19, Finished, Available, Finished)
# builtin				       launch_container.sh
# container_tokens		       __spark_conf__
# default_container_executor_session.sh  sparkr
# default_container_executor.sh	       tmp
# env

# %%
os.chdir(BRONZE_DATA_PATH)
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 24, Finished, Available, Finished)

# %%
print(os.getcwd())
# !ls .
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 25, Finished, Available, Finished)
# /lakehouse/default/Files/bronze

# %%
api.dataset_download_files(dataset = KAGGLE_DATASET, unzip=True)
# Out:
# StatementMeta(, 8a06f850-19f1-42af-9ddf-2ce1e00106f1, 26, Finished, Available, Finished)
# Dataset URL: https://www.kaggle.com/datasets/nishiodens/japan-real-estate-transaction-prices
